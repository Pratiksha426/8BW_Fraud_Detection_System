# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratiksha426/8BW_Fraud_Detection_System/blob/main/Fraud_Detection_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MACHINE LEARNING INTERNSHIP
#
# TASK - 4
#
# TOPIC - FRAUD DETECTION SYSTEM ON FINANCIAL TRANSACTIONS
#
# CREATED BY- PRATIKSHA KUMBHARE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/dt.csv')

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0      0.0             0.0
# 1  M2044282225             0.0             0.0      0.0             0.0
# 2   C553264065             0.0             0.0      1.0             0.0
# 3    C38997010         21182.0             0.0      1.0             0.0
# 4  M1230701703             0.0             0.0      0.0             0.0

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     1
# newbalanceOrig    1
# nameDest          1
# oldbalanceDest    1
# newbalanceDest    1
# isFraud           1
# isFlaggedFraud    1
# dtype: int64

# %%
df.shape
# Out:
# (14247, 11)

# %%
df.type.value_counts()
# Out:
# PAYMENT     7869
# CASH_IN     2472
# CASH_OUT    2055
# TRANSFER    1438
# DEBIT        413
# Name: type, dtype: int64

# %%
transactions=df.type.index

# %%
quantity=df.type.values

# %%
df=df.dropna()

# %%
df
# Out:
#        step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0         1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1         1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2         1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3         1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4         1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
# ...     ...       ...       ...          ...            ...             ...
# 14241     8   PAYMENT  35108.12  C1925841262            0.0            0.00
# 14242     8   PAYMENT  20924.47  C1540995845        18265.0            0.00
# 14243     8  CASH_OUT  75244.54  C1827218030        38369.0            0.00
# 14244     8   PAYMENT   3074.36  C1632817923        10242.0         7167.64
# 14245     8   PAYMENT  11465.21  C1837637612           38.0            0.00
#
# ...

# %%
df['isFraud']=df['isFraud'].map({0:'No Fraud',1:'Fraud'})

# %%
df['type'].unique()
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
#       dtype=object)

# %%
df['type'].value_counts()
# Out:
# PAYMENT     7869
# CASH_IN     2472
# CASH_OUT    2054
# TRANSFER    1438
# DEBIT        413
# Name: type, dtype: int64

# %%
df['type']=df['type'].map({'PAYMENT':1, 'TRANSFER':4, 'CASH_OUT':2, 'DEBIT':5, 'CASH_IN':3})

# %%
df['type'].value_counts()
# Out:
# 1    7869
# 3    2472
# 2    2054
# 4    1438
# 5     413
# Name: type, dtype: int64

# %%
df
# Out:
#        step  type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0         1     1   9839.64  C1231006815       170136.0       160296.36
# 1         1     1   1864.28  C1666544295        21249.0        19384.72
# 2         1     4    181.00  C1305486145          181.0            0.00
# 3         1     2    181.00   C840083671          181.0            0.00
# 4         1     1  11668.14  C2048537720        41554.0        29885.86
# ...     ...   ...       ...          ...            ...             ...
# 14241     8     1  35108.12  C1925841262            0.0            0.00
# 14242     8     1  20924.47  C1540995845        18265.0            0.00
# 14243     8     2  75244.54  C1827218030        38369.0            0.00
# 14244     8     1   3074.36  C1632817923        10242.0         7167.64
# 14245     8     1  11465.21  C1837637612           38.0            0.00
#
#           nameDest  oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud
# ...

# %%
df['type'].value_counts()
# Out:
# 1    7869
# 3    2472
# 2    2054
# 4    1438
# 5     413
# Name: type, dtype: int64

# %%
df['type'].value_counts()
# Out:
# 1    7869
# 3    2472
# 2    2054
# 4    1438
# 5     413
# Name: type, dtype: int64

# %%
x=df[['type','amount','oldbalanceOrg','newbalanceOrig']]

# %%
y=df.iloc[:,-2]

# %%
y
# Out:
# 0        No Fraud
# 1        No Fraud
# 2           Fraud
# 3           Fraud
# 4        No Fraud
#            ...
# 14241    No Fraud
# 14242    No Fraud
# 14243    No Fraud
# 14244    No Fraud
# 14245    No Fraud
# Name: isFraud, Length: 14246, dtype: object

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model.score(xtest,ytest)
# Out:
# 0.9982456140350877

# %%
model.predict([[4,180,181,10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['No Fraud'], dtype=object)
